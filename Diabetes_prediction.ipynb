# %%
import numpy as np
import pandas as pd
import pickle
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('/content/diabetes.csv') #loading dataset to pandas dataframe
data = data.drop('Pregnancies', axis=1)

# %%
data.head() #printing first 5 rows.
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35        0  33.6
# 1       85             66             29        0  26.6
# 2      183             64              0        0  23.3
# 3       89             66             23       94  28.1
# 4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.shape #printing total number of rows and columns.
# Out:
# (768, 8)

# %%
data.describe() #statistical measurements of the data.
# Out:
#           Glucose  BloodPressure  SkinThickness     Insulin         BMI  \
# count  768.000000     768.000000     768.000000  768.000000  768.000000
# mean   120.894531      69.105469      20.536458   79.799479   31.992578
# std     31.972618      19.355807      15.952218  115.244002    7.884160
# min      0.000000       0.000000       0.000000    0.000000    0.000000
# 25%     99.000000      62.000000       0.000000    0.000000   27.300000
# 50%    117.000000      72.000000      23.000000   30.500000   32.000000
# 75%    140.250000      80.000000      32.000000  127.250000   36.600000
# max    199.000000     122.000000      99.000000  846.000000   67.100000
#
#        DiabetesPedigreeFunction         Age     Outcome
# count                768.000000  768.000000  768.000000
# mean                   0.471876   33.240885    0.348958
# std                    0.331329   11.760232    0.476951
# min                    0.078000   21.000000    0.000000
# ...

# %%
data['Outcome'].value_counts() #total number of diabetic and non-diabetic patients.
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
data.groupby('Outcome').mean() #mean values of diabetic and non-diabetic patients.
# Out:
#             Glucose  BloodPressure  SkinThickness     Insulin        BMI  \
# Outcome
# 0        109.980000      68.184000      19.664000   68.792000  30.304200
# 1        141.257463      70.824627      22.164179  100.335821  35.142537
#
#          DiabetesPedigreeFunction        Age
# Outcome
# 0                        0.429734  31.190000
# 1                        0.550500  37.067164

# %%
#SPLITING LABELS IN DATASET
x = data.drop(columns = 'Outcome', axis=1) #storing dataset except Outcome column.
y = data['Outcome'] #storing outcome column.

# %%
print(x)
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             72             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3         89             66             23       94  28.1
# 4        137             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 763      101             76             48      180  32.9
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 766      126             60              0        0  30.1
# 767       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# ...

# %%
print(y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
scaler = StandardScaler() #creating scaler object.

# %%
scaler.fit(x) #fitting the data.
# Out:
# StandardScaler()

# %%
std_data = scaler.transform(x) #standardizing the data.

# %%
pickle.dump(scaler, open('scaler.sav', 'wb'))

# %%
print(std_data)
# Out:
# [[ 0.84832379  0.14964075  0.90726993 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-1.12339636 -0.16054575  0.53090156 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.94372388 -0.26394125 -1.28821221 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.00330087  0.14964075  0.15453319 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [ 0.1597866  -0.47073225 -1.28821221 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.8730192   0.04624525  0.65635768 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
x = std_data
y = data['Outcome']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=2) #splitting data into training and testing data.

# %%
print(x.shape, x_train.shape, x_test.shape) #printing shape of x, x_train and x_test.
# Out:
# (768, 7) (614, 7) (154, 7)

# %% [markdown]
# # Support Vector Machine

# %%
svm_classifier = svm.SVC(kernel='linear') #creating svm classifier object.
svm_classifier.fit(x_train, y_train) #training the model.
# Out:
# SVC(kernel='linear')

# %%
svm_train_pred = svm_classifier.predict(x_train)
svm_train_accuracy = accuracy_score(y_train, svm_train_pred)
print('SVM - Training Accuracy:', svm_train_accuracy)

svm_test_pred = svm_classifier.predict(x_test)
svm_test_accuracy = accuracy_score(y_test, svm_test_pred)
print('SVM - Testing Accuracy:', svm_test_accuracy)
# Out:
# SVM - Training Accuracy: 0.7850162866449512
# SVM - Testing Accuracy: 0.7662337662337663

# %% [markdown]
# # Logistic Regression

# %%
lr_classifier = LogisticRegression()
lr_classifier.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr_train_pred = lr_classifier.predict(x_train)
lr_train_accuracy = accuracy_score(y_train, lr_train_pred)
print('Logistic Regression - Training Accuracy:', lr_train_accuracy)

lr_test_pred = lr_classifier.predict(x_test)
lr_test_accuracy = accuracy_score(y_test, lr_test_pred)
print('Logistic Regression - Testing Accuracy:', lr_test_accuracy)
# Out:
# Logistic Regression - Training Accuracy: 0.7833876221498371
# Logistic Regression - Testing Accuracy: 0.7532467532467533

# %% [markdown]
# # Decision Tree

# %%
dt_classifier = DecisionTreeClassifier(max_depth=5, min_samples_split=10, min_samples_leaf=5)
dt_classifier.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=5, min_samples_split=10)

# %%
dt_train_pred = dt_classifier.predict(x_train)
dt_train_accuracy = accuracy_score(y_train, dt_train_pred)
print('Decision Tree - Training Accuracy:', dt_train_accuracy)

dt_test_pred = dt_classifier.predict(x_test)
dt_test_accuracy = accuracy_score(y_test, dt_test_pred)
print('Decision Tree - Testing Accuracy:', dt_test_accuracy)
# Out:
# Decision Tree - Training Accuracy: 0.8306188925081434
# Decision Tree - Testing Accuracy: 0.7597402597402597

# %% [markdown]
# # Random Forest

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, max_depth=20, min_samples_split=5, min_samples_leaf=4, bootstrap=True, random_state=42)
rf_classifier.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=20, min_samples_leaf=4, min_samples_split=5,
#                        random_state=42)

# %%
rf_train_pred = rf_classifier.predict(x_train)
rf_train_accuracy = accuracy_score(y_train, rf_train_pred)
print('Random Forest - Training Accuracy:', rf_train_accuracy)

rf_test_pred = rf_classifier.predict(x_test)
rf_test_accuracy = accuracy_score(y_test, rf_test_pred)
print('Random Forest - Testing Accuracy:', rf_test_accuracy)
# Out:
# Random Forest - Training Accuracy: 0.9136807817589576
# Random Forest - Testing Accuracy: 0.7662337662337663

# %%
input_data = (110,92,0,0,37.6,0.191,30) #taking input from user(non-diabetic).
#input_data = (148,72,35,0,33.6,0.627,50) #taking input from user(diabetic).

input_data_as_numpy_array = np.asarray(input_data) #converting input data into numpy array for easy processing.

input_data_reshaped = input_data_as_numpy_array.reshape(1,-1) #reshaping the input data.

std_data = scaler.transform(input_data_reshaped) #standardizing the input data.
print(std_data)

prediction = dt_classifier.predict(std_data) #making prediction on the input data.
print(prediction)

if prediction[0] == 0:
  print('The person is not diabetic.')
else:
  print('The person is diabetic.')
# Out:
# [[-0.34096773  1.18359575 -1.28821221 -0.69289057  0.71168975 -0.84827977
#   -0.27575966]]
# [0]
# The person is not diabetic.

# %%
import pickle

# %%
filename = 'trained_model.sav' #naming the pickle file as 'trained_model'.
pickle.dump(svm_classifier, open(filename, 'wb')) #saving the trained model.

# %%
loaded_model = pickle.load(open('trained_model.sav', 'rb')) #loading the saved model.

# %%
input_data = (110,92,0,0,37.6,0.191,30) #taking input from user(non-diabetic).
#input_data = (148,72,35,0,33.6,0.627,50) #taking input from user(diabetic).

input_data_as_numpy_array = np.asarray(input_data) #converting input data into numpy array for easy processing.

input_data_reshaped = input_data_as_numpy_array.reshape(1,-1) #reshaping the input data.

std_data = scaler.transform(input_data_reshaped) #standardizing the input data.
print(std_data)

prediction = loaded_model.predict(std_data) #making prediction on the input data.
print(prediction)

if prediction[0] == 0:
  print('The person is not diabetic.')
else:
  print('The person is diabetic.')
# Out:
# [[-0.34096773  1.18359575 -1.28821221 -0.69289057  0.71168975 -0.84827977
#   -0.27575966]]
# [0]
# The person is not diabetic.
